# %%
import pandas as pd
import seaborn as sns
import random

# %%
df = pd.read_csv('california_housing_train.csv')

# %% [markdown]
# Изобразите отношение households к population с помощью точечного графика

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
sns.scatterplot(data=df, x="households", y ="population")
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %% [markdown]
# Визуализировать longitude по отношения к median_house_value, используя линейный график

# %%
sns.relplot(data=df, x = 'longitude', y = 'median_house_value', kind = 'line', height = 10, aspect = 4)

# %% [markdown]
# Представить гистограмму по housing_median_age

# %%
sns.histplot(data = df, x ='housing_median_age')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %% [markdown]
# Изобразить гистограмму по median_house_value с оттенком housing_median_age

# %%
sns.histplot(data = df, x ='housing_median_age', hue = 'housing_median_age',legend=False)
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %%
sns.displot(df, x="median_house_value", hue="housing_median_age",  bins=range(0, 5000001, 50000))

# %%
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  human
# 1  human
# 2  robot
# 3  human
# 4  human

# %%
pd.get_dummies(data)
# Out:
#     whoAmI_human  whoAmI_robot
# 0              1             0
# 1              1             0
# 2              0             1
# 3              1             0
# 4              1             0
# 5              0             1
# 6              0             1
# 7              0             1
# 8              0             1
# 9              0             1
# 10             0             1
# 11             1             0
# 12             1             0
# 13             1             0
# 14             0             1
# 15             1             0
# 16             0             1
# 17             1             0
# 18             0             1
# 19             1             0

# %%
new_data = data.copy()
new_data['res']= new_data.apply(lambda x: x == 'robot' if x.name in ['whoAmI'] else x, axis=0)
new_data
# Out:
#    whoAmI    res
# 0   human  False
# 1   human  False
# 2   robot   True
# 3   human  False
# 4   human  False
# 5   robot   True
# 6   robot   True
# 7   robot   True
# 8   robot   True
# 9   robot   True
# 10  robot   True
# 11  human  False
# 12  human  False
# 13  human  False
# 14  robot   True
# 15  human  False
# 16  robot   True
# 17  human  False
# 18  robot   True
# 19  human  False
